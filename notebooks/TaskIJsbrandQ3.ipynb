# %%
from simulations.drosselschwab import simulate_drosselschwab
import results
import data

# Then when saving a file you can use the path function like so:
results_path = results.path('p_param_2.csv')
data_path = data.path('p_param_2.csv')
print(results_path, data_path)
# Out:
# /home/ijsbrand/CMS/CS/Project/CSS_project-19/notebooks/../results/p_param_2.csv /home/ijsbrand/CMS/CS/Project/CSS_project-19/notebooks/../data/p_param_2.csv

# %%
L = 256
p = 0.01
f = 0.0001
steps = 10000

print("Start experiment:")

fire_sizes, grid = simulate_drosselschwab(L=L, p=p, f=f, steps=steps)
# Out:
# Start experiment:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       4 steps = 10000
#       6 print("Start experiment:")
# ----> 8 fire_sizes, grid = simulate_drosselschwab(L=L, p=p, f=f, steps=steps)
#
# File ~/CMS/CS/Project/CSS_project-19/notebooks/../simulations/drosselschwab.py:10, in simulate_drosselschwab(L, p, f, steps)
#       6 def _compute_cluster_sizes(grid, connectivity=4):
#       7     """Compute sizes of connected tree clusters (value==1) in grid without modifying it.
#       8     Uses iterative flood-fill (stack/DFS) and returns a list of cluster sizes.
#       9     """
# ---> 10     Lx, Ly = grid.shape
#      11     visited = np.zeros_like(grid, dtype=bool)
#      12     clusters = []
#
# File ~/CMS/CS/Project/CSS_project-19/notebooks/../src/drosselschwab.py:70, in step(grid, fire_sizes, L, p, f)
#      67 grid[empty_mask] = np.array(growth_roll < p, dtype=np.int8)
#      69 # 2. Lightning Phase: Trees are struck with probability f [cite: 49]
# ---> 70 tree_indices = np.argwhere(grid == 1)
#      71 if len(tree_indices) > 0:
#      72     lightning_roll = np.random.random(len(tree_indices))
#
# File ~/CMS/CS/Project/.venv/lib/python3.11/site-packages/numpy/_core/numeric.py:672, in argwhere(a)
#     670     # then remove the added dimension
#     671     return argwhere(a)[:, :0]
# --> 672 return transpose(nonzero(a))
#
# File ~/CMS/CS/Project/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2077, in nonzero(a)
#    1993 @array_function_dispatch(_nonzero_dispatcher)
#    1994 def nonzero(a):
#    1995     """
#    1996     Return the indices of the elements that are non-zero.
#    1997
#    (...)   2075
#    2076     """
# -> 2077     return _wrapfunc(a, 'nonzero')
#
# File ~/CMS/CS/Project/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      51     return _wrapit(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#      63     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
