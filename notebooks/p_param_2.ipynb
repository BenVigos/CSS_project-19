# %%
from simulations.drosselschwab import simulate_drosselschwab
import results
import data
# Out:
# /Users/andrew/Desktop/Computational Science/ComplexSystems/wildfires/results/p_param_2.csv
# /Users/andrew/Desktop/Computational Science/ComplexSystems/wildfires/data/p_param_2.csv
